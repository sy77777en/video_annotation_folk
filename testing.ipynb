# %%
import os
import json
import logging

def find_json_files(root_dir: str) -> list:
    """Find all JSON files in the given directory and its subdirectories."""
    json_files = []
    
    logging.info(f"Searching for JSON files in: {root_dir}")
    
    for root, _, files in os.walk(root_dir):
        for file in files:
            if file.endswith('.json'):
                full_path = os.path.join(root, file)
                # Get relative path from root_dir
                rel_path = os.path.relpath(full_path, root_dir)
                json_files.append(rel_path)
    
    return sorted(json_files)  # Sort for consistent output

def main():
    # Set up logging
    logging.basicConfig(level=logging.INFO,
                       format='%(asctime)s - %(levelname)s - %(message)s')
    
    # Get the labels directory path
    labels_dir = "labels"  # Adjust this path if needed
    
    try:
        # Find all JSON files
        json_files = find_json_files(labels_dir)
        
        # Print the results
        print("\nFound JSON files:")
        for file_path in json_files:
            print(file_path)
        
        print(f"\nTotal JSON files found: {len(json_files)}")
        
    except Exception as e:
        logging.error(f"Error processing directory: {str(e)}")
        return 1
    
    return json_files  # Return the files instead of an exit code

if __name__ == "__main__":
    main()  # When run as a script, just call main()
# Out:
# 2025-02-03 07:54:36,098 - INFO - Searching for JSON files in: labels
# Found JSON files:
# cam_motion/arc_crane_movement/arc_clockwise/has_arc_clockwise.json
# cam_motion/arc_crane_movement/arc_counterclockwise/has_arc_counterclockwise.json
# cam_motion/arc_crane_movement/crane_down/has_crane_down.json
# cam_motion/arc_crane_movement/crane_up/has_crane_up.json
# cam_motion/camera_centric_movement/backward/has_backward_wrt_camera.json
# cam_motion/camera_centric_movement/backward/only_backward_wrt_camera.json
# cam_motion/camera_centric_movement/downward/has_downward_wrt_camera.json
# cam_motion/camera_centric_movement/downward/only_downward_wrt_camera.json
# cam_motion/camera_centric_movement/forward/has_forward_wrt_camera.json
# cam_motion/camera_centric_movement/forward/only_forward_wrt_camera.json
# cam_motion/camera_centric_movement/leftward/has_leftward.json
# cam_motion/camera_centric_movement/leftward/only_leftward.json
# cam_motion/camera_centric_movement/pan_left/has_pan_left.json
# cam_motion/camera_centric_movement/pan_left/only_pan_left.json
# cam_motion/camera_centric_movement/pan_right/has_pan_right.json
# cam_motion/camera_centric_movement/pan_right/only_pan_right.json
# cam_motion/camera_centric_movement/rightward/has_rightward.json
# cam_motion/camera_centric_movement/rightward/only_rightward.json
# cam_motion/camera_centric_movement/roll_clockwise/has_roll_clockwise.json
# cam_motion/camera_centric_movement/roll_clockwise/only_roll_clockwise.json
# cam_motion/camera_centric_movement/roll_counterclockwise/has_roll_counterclockwise.json
# cam_motion/camera_centric_movement/roll_counterclockwise/only_roll_counterclockwise.json
# cam_motion/camera_centric_movement/tilt_down/has_tilt_down.json
# cam_motion/camera_centric_movement/tilt_down/only_tilt_down.json
# cam_motion/camera_centric_movement/tilt_up/has_tilt_up.json
# cam_motion/camera_centric_movement/tilt_up/only_tilt_up.json
# cam_motion/camera_centric_movement/upward/has_upward_wrt_camera.json
# cam_motion/camera_centric_movement/upward/only_upward_wrt_camera.json
# cam_motion/dolly_zoom_movement/has_dolly_in_zoom_out.json
# cam_motion/dolly_zoom_movement/has_dolly_out_zoom_in.json
# cam_motion/ground_centric_movement/backward/has_backward_wrt_ground.json
# cam_motion/ground_centric_movement/backward/has_backward_wrt_ground_birds_worms_included.json
# cam_motion/ground_centric_movement/backward/only_backward_wrt_ground.json
# cam_motion/ground_centric_movement/backward/only_backward_wrt_ground_birds_worms_included.json
# cam_motion/ground_centric_movement/downward/has_downward_wrt_ground.json
# cam_motion/ground_centric_movement/downward/has_downward_wrt_ground_birds_worms_included.json
# cam_motion/ground_centric_movement/downward/only_downward_wrt_ground.json
# cam_motion/ground_centric_movement/downward/only_downward_wrt_ground_birds_worms_included.json
# cam_motion/ground_centric_movement/forward/has_forward_wrt_ground.json
# cam_motion/ground_centric_movement/forward/has_forward_wrt_ground_birds_worms_included.json
# cam_motion/ground_centric_movement/forward/only_forward_wrt_ground.json
# cam_motion/ground_centric_movement/forward/only_forward_wrt_ground_birds_worms_included.json
# cam_motion/ground_centric_movement/upward/has_upward_wrt_ground.json
# cam_motion/ground_centric_movement/upward/has_upward_wrt_ground_birds_worms_included.json
# cam_motion/ground_centric_movement/upward/only_upward_wrt_ground.json
# cam_motion/ground_centric_movement/upward/only_upward_wrt_ground_birds_worms_included.json
# cam_motion/has_frame_freezing.json
# cam_motion/has_motion_blur.json
# cam_motion/has_shot_transition_cam_motion.json
# cam_motion/motion_complexity/is_complex_motion.json
# cam_motion/motion_complexity/is_minor_motion.json
# cam_motion/motion_complexity/is_simple_motion.json
# cam_motion/object_centric_movement/aerial_tracking_shot.json
# cam_motion/object_centric_movement/arc_tracking_shot.json
# cam_motion/object_centric_movement/front_side_tracking_shot.json
# cam_motion/object_centric_movement/lead_tracking_shot.json
# cam_motion/object_centric_movement/pan_tracking_shot.json
# cam_motion/object_centric_movement/rear_side_tracking_shot.json
# cam_motion/object_centric_movement/side_tracking_shot.json
# cam_motion/object_centric_movement/tail_tracking_shot.json
# cam_motion/object_centric_movement/tilt_tracking_shot.json
# cam_motion/object_centric_movement/track_shot.json
# cam_motion/object_centric_movement/tracking_subject_larger_size.json
# cam_motion/object_centric_movement/tracking_subject_smaller_size.json
# cam_motion/scene_movement/dynamic_scene.json
# cam_motion/scene_movement/mostly_static_scene.json
# cam_motion/scene_movement/static_scene.json
# cam_motion/steadiness_and_movement/clear_moving_camera.json
# cam_motion/steadiness_and_movement/fast_moving_camera.json
# cam_motion/steadiness_and_movement/fixed_camera.json
# cam_motion/steadiness_and_movement/fixed_camera_with_shake.json
# cam_motion/steadiness_and_movement/moving_camera.json
# cam_motion/steadiness_and_movement/shaky_camera.json
# cam_motion/steadiness_and_movement/slow_moving_camera.json
# cam_motion/steadiness_and_movement/stable_camera.json
# cam_motion/steadiness_and_movement/very_shaky_camera.json
# cam_motion/steadiness_and_movement/very_stable_camera.json
# cam_setup/has_overlays.json
# cam_setup/has_shot_transition_cam_setup.json
# cam_setup/lens_distortion/fisheye_distortion.json
# cam_setup/lens_distortion/no_lens_distortion.json
# cam_setup/lens_distortion/with_lens_distortion.json
# cam_setup/point_of_view/broadcast_pov.json
# cam_setup/point_of_view/dashcam_pov.json
# cam_setup/point_of_view/drone_pov.json
# cam_setup/point_of_view/first_person_pov.json
# cam_setup/point_of_view/locked_on_pov.json
# cam_setup/point_of_view/overhead_pov.json
# cam_setup/point_of_view/screen_recording_pov.json
# cam_setup/point_of_view/selfie_pov.json
# cam_setup/point_of_view/third_person_full_body_game_pov.json
# cam_setup/point_of_view/third_person_isometric_game_pov.json
# cam_setup/point_of_view/third_person_over_hip_pov.json
# cam_setup/point_of_view/third_person_over_shoulder_pov.json
# cam_setup/point_of_view/third_person_side_view_game_pov.json
# cam_setup/point_of_view/third_person_top_down_game_pov.json
# cam_setup/video_speed/fast_motion.json
# cam_setup/video_speed/fast_motion_without_time_lapse.json
# cam_setup/video_speed/regular_speed.json
# cam_setup/video_speed/slow_motion.json
# cam_setup/video_speed/speed_ramp.json
# cam_setup/video_speed/stop_motion.json
# cam_setup/video_speed/time_lapse.json
# cam_setup/video_speed/time_reversed.json
#
# Total JSON files found: 104
